# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
# help(requests)

# %%
url = 'http://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
#for x in range(5):
    #data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][x]['Driver']['familyName']
    #print(data)
my_racer_data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
my_racer_data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
def get_racer_data(data):
    new_data = []
    for racer in data:
        racer_dict = {}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        racer_dict[racer_name] = {
                'First_name':racer['Driver']['givenName'],
                'Last_name':racer['Driver']['familyName'],
                'position':racer['position'],
                'wins':racer['wins'],
                'DOB':racer['Driver']['dateOfBirth'],
                'nationality':racer['Driver']['nationality'],
                'Constructors':racer['Constructors'][0]['name'] 
                }
        new_data.append(racer_dict)
    return new_data
get_racer_data(my_racer_data)
# Out:
# [{'Kimi Räikkönen': {'First_name': 'Kimi',
#    'Last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'Constructors': 'Ferrari'}},
#  {'Felipe Massa': {'First_name': 'Felipe',
#    'Last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'Constructors': 'Ferrari'}},
#  {'Lewis Hamilton': {'First_name': 'Lewis',
#    'Last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'Constructors': 'McLaren'}},
#  {'Robert Kubica': {'First_name': 'Robert',
#    'Last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'Constructors': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'First_name': 'Nick',
#    'Last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year, r):
    Url = f'http://ergast.com/api/f1/{year}/{r}/driverStandings.json'
    response = requests.get(Url)
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return 'We had an error loading your data It is likely yer and round not in the database '
    data =response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_data(data)
get_driver_info_by_year_and_round(2019, 4)
# Out:
# [{'Valtteri Bottas': {'First_name': 'Valtteri',
#    'Last_name': 'Bottas',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1989-08-28',
#    'nationality': 'Finnish',
#    'Constructors': 'Mercedes'}},
#  {'Lewis Hamilton': {'First_name': 'Lewis',
#    'Last_name': 'Hamilton',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'Constructors': 'Mercedes'}},
#  {'Sebastian Vettel': {'First_name': 'Sebastian',
#    'Last_name': 'Vettel',
#    'position': '3',
#    'wins': '0',
#    'DOB': '1987-07-03',
#    'nationality': 'German',
#    'Constructors': 'Ferrari'}},
#  {'Max Verstappen': {'First_name': 'Max',
#    'Last_name': 'Verstappen',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1997-09-30',
#    'nationality': 'Dutch',
#    'Constructors': 'Red Bull'}},
#  {'Charles Leclerc': {'First_name': 'Charles',
#    'Last_name': 'Leclerc',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1997-10-16',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
import requests

def get_pokemon_info(data):
  
    # List of 5 pokemon names to query for
    pokemon_names = ['pikachu', 'charizard', 'squirtle', 'bulbasaur', 'eevee']
    
    # Empty list to store the data for each pokemon 
    new_data = []
    
    # Loop through each pokemon name and make a request to the PokeAPI
    for name in pokemon_names:
        # Make request to the API
        response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{name}')
        pokemon_data = response.json()
        pokemon_data 
        # Extract the required data from the response
        pokemon_dict={}
        pokemon_dict['name'] =pokemon_data ['name']
        pokemon_dict['ability_name'] = pokemon_data['abilities'][0]['ability']['name']
        pokemon_dict['base_experience'] = pokemon_data['base_experience']
        pokemon_dict['sprite_url'] = pokemon_data['sprites']['front_shiny']
        pokemon_dict['attack'] = pokemon_data['stats'][1]['base_stat']
        pokemon_dict['hp'] = pokemon_data['stats'][0]['base_stat']
        pokemon_dict ['defense'] = pokemon_data['stats'][2]['base_stat']
        
    # Append the pokemon data to the list
        new_data.append(pokemon_dict)
    return new_data
get_pokemon_info(pokemon_data )
# Out:
# [{'name': 'pikachu',
#   'ability_name': 'static',
#   'base_experience': 112,
#   'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/25.png',
#   'attack': 55,
#   'hp': 35,
#   'defense': 40},
#  {'name': 'charizard',
#   'ability_name': 'blaze',
#   'base_experience': 267,
#   'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png',
#   'attack': 84,
#   'hp': 78,
#   'defense': 78},
#  {'name': 'squirtle',
#   'ability_name': 'torrent',
#   'base_experience': 63,
#   'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/7.png',
#   'attack': 48,
#   'hp': 44,
#   'defense': 65},
#  {'name': 'bulbasaur',
#   'ability_name': 'overgrow',
#   'base_experience': 64,
#   'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png',
#   'attack': 49,
#   'hp': 45,
#   'defense': 49},
#  {'name': 'eevee',
# ...

# %%
import requests

# Base URL for the PokeAPI
base_url = "https://pokeapi.co/api/v2/pokemon/"

# Function to fetch details of a single Pokemon
def fetch_pokemon_details(pokemon_name):
    response = requests.get(base_url + pokemon_name)
    data = response.json()
    
    # Extracting required details
    abilities = [ability['ability']['name'] for ability in data['abilities']]
    types = [type_['type']['name'] for type_ in data['types']]
    weight = data['weight']
    
    return {
        'abilities': abilities,
        'weight': weight,
        'types': types
    }

# Fetching the list of the first 20 Pokémon
response = requests.get(base_url + "?limit=20")
all_pokemon = response.json()['results']

# Constructing the dictionary

pokemon_dict = {}

for pokemon in all_pokemon:
    details = fetch_pokemon_details(pokemon['name'])
    for type_ in details['types']:
        if type_ not in pokemon_dict:
            pokemon_dict[type_] = {}
        pokemon_dict[type_][pokemon['name']] = {
            'abilities': details['abilities'],
            'weight': details['weight']
        }
   

print(pokemon_dict)
# Out:
# {'grass': {'bulbasaur': {'abilities': ['overgrow', 'chlorophyll'], 'weight': 69}, 'ivysaur': {'abilities': ['overgrow', 'chlorophyll'], 'weight': 130}, 'venusaur': {'abilities': ['overgrow', 'chlorophyll'], 'weight': 1000}}, 'poison': {'bulbasaur': {'abilities': ['overgrow', 'chlorophyll'], 'weight': 69}, 'ivysaur': {'abilities': ['overgrow', 'chlorophyll'], 'weight': 130}, 'venusaur': {'abilities': ['overgrow', 'chlorophyll'], 'weight': 1000}, 'weedle': {'abilities': ['shield-dust', 'run-away'], 'weight': 32}, 'kakuna': {'abilities': ['shed-skin'], 'weight': 100}, 'beedrill': {'abilities': ['swarm', 'sniper'], 'weight': 295}}, 'fire': {'charmander': {'abilities': ['blaze', 'solar-power'], 'weight': 85}, 'charmeleon': {'abilities': ['blaze', 'solar-power'], 'weight': 190}, 'charizard': {'abilities': ['blaze', 'solar-power'], 'weight': 905}}, 'flying': {'charizard': {'abilities': ['blaze', 'solar-power'], 'weight': 905}, 'butterfree': {'abilities': ['compound-eyes', 'tinted-lens'], 'w
# ...
